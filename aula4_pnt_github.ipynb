# %% [markdown]
# <a href="https://colab.research.google.com/github/LNS127/LNS127/blob/main/aula4_pnt_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ETE CICERO DIAS
#DOCENTE: CLOVES
#ESTUDANTE: LUCAS
#ESTUDANTE: CLAUDINEI

print('Lucas')
L=  False
print(type(L))
# Out:
# Lucas
# <class 'bool'>
