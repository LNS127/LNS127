# %% [markdown]
# <a href="https://colab.research.google.com/github/LNS127/LNS127/blob/main/AT1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Questão 1

# %%
print('Olá ETE Cícero Dias! ')
# Out:
# Olá ETE Cícero Dias!

# %% [markdown]
# Questão 2

# %%
num = float(input( 'Digite um número: ' ))
print ('O número informado foi:', num)
# Out:
# Digite um número: 2.5
# O número informado foi: 2.5

# %% [markdown]
# Questão 3

# %%
n1= float(input('Digite o primeiro número: '))
n2= float(input('Digite o segundo número: '))
print (n1+n2)
# Out:
# Digite o primeiro número: 15
# Digite o segundo número: 18.5
# 33.5

# %% [markdown]
# Questão 4

# %%
[n1= float(input('A sua Primeira Nota é: '))
n2= float(input('A sua Segunda Nota é: '))
n3= float(input('A sua Terceira Nota é: '))
n4= float(input('A sua Quarta Nota é: '))
mf= (n1+n2+n3+n4)/4
print(f'A sua Média Final é: {mf}')
# Out:
# A sua Primeira Nota é: 8
# A sua Segunda Nota é: 9
# A sua Terceira Nota é: 10
# A sua Quarta Nota é: 7.5
# A sua Média Final é: 8.625

# %% [markdown]
# Questão 5

# %%
m = float(input('A distância em metros é: '))
c = m*100
print(f'{m} equivalem a {c} cm')
# Out:
# A distância em metros é: 200
# 200.0 equivalem a 20000.0 cm

# %% [markdown]
# Questão 6

# %%
r= float(input('O Raio é do círculo é: '))
a = 3,14 * r**2
print(f'A área do círculo é: {a}')
# Out:
# O Raio é do círculo é: 4
# A área do círculo é: (3, 224.0)

# %% [markdown]
# Questão 7

# %%
l= float(input('Qual o valor do lado do quadrado? '))
a= l**2
d= a*2
print(f'A área do quadrado é: {a} cm ')
print (f'O dobro da área é: {d} cm ')
# Out:
# Qual o valor do lado do quadrado? 5
# A área do quadrado é: 25.0 cm
# O dobro da área é: 50.0 cm

# %% [markdown]
# Questão 8

# %%
v= float(input('Quanto voçê ganha por hora trabalhada? '))
h= float (input('Quantas horas voçê trabalha por mês? '))
r= v*h
print(f'Seu sálario por mês é: R$ {r} ')
# Out:
# Quanto voçê ganha por hora trabalhada? 7
# Quantas horas voçê trabalha por mês? 204
# Seu sálario por mês é: R$ 1428.0

# %% [markdown]
# Questão 9

# %%
n= float(input('Digite um número: '))
if n > 0:
 print('Esse número é positivo.')
else:
 print('Esse número é negativo. ')
# Out:
# Digite um número: -10
# Esse número é negativo.

# %% [markdown]
# Questão 10

# %%
l= input('Digite uma letra: ')
if (l == "F") or (l=="f"):

 print('Sexo Feminino')

elif (l== "M") or (l=="m"):
 print('Sexo Masculino')

else:
 print('Sexo Inválido')
# Out:
# Digite uma letra: f
# Sexo Feminino

# %% [markdown]
# Lucas Nascimento DS1 A
